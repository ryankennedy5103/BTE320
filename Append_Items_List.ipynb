# %% [markdown]
# <a href="https://colab.research.google.com/github/ryankennedy5103/BTE320/blob/main/Append_Items_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = []

num = float(input('Give a number: '))
while num != 0:
    numbers.append(num)
    num = float(input('Give another number: '))

numbers.sort(reverse=True)
print(numbers)
