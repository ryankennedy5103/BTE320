# %% [markdown]
# <a href="https://colab.research.google.com/github/ryankennedy5103/BTE320/blob/main/Movie_Theater.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for ad in range(0, 201, 25):
  revenue = 10 * (20 + 2 * ad ** 0.5) - 200 - ad
  print(ad, round(revenue, 1))
# Out:
# 0 0.0
# 25 75.0
# 50 91.4
# 75 98.2
# 100 100.0
# 125 98.6
# 150 94.9
# 175 89.6
# 200 82.8
